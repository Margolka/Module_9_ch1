# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
genres = pd.read_csv('tmdb_genres.csv')
genres['genres']=genres['genres'].fillna('unclassified')
genres.rename(columns={ genres.columns[0]: "genre_id" },inplace=True)
genres
# Out:
#     genre_id           genres
# 0       28.0           Action
# 1       12.0        Adventure
# 2       14.0          Fantasy
# 3       16.0        Animation
# 4      878.0  Science Fiction
# 5       18.0            Drama
# 6       53.0         Thriller
# 7    10751.0           Family
# 8       35.0           Comedy
# 9       36.0          History
# 10   10752.0              War
# 11      37.0          Western
# 12   10749.0          Romance
# 13      80.0            Crime
# 14    9648.0          Mystery
# 15      27.0           Horror
# 16      99.0      Documentary
# 17   10402.0            Music
# 18   10770.0         TV Movie
# 19       NaN     unclassified
# 20   10769.0          Foreign

# %%
movies = pd.read_csv('tmdb_movies.csv')
movies.head()
# Out:
#    Unnamed: 0     budget                                      homepage  \
# 0           0  237000000                   http://www.avatarmovie.com/
# 1           1  300000000  http://disney.go.com/disneypictures/pirates/
# 2           2  245000000   http://www.sonypictures.com/movies/spectre/
# 3           3  250000000            http://www.thedarkknightrises.com/
# 4           4  260000000          http://movies.disney.com/john-carter
#
#        id original_language                            original_title  \
# 0   19995                en                                    Avatar
# 1     285                en  Pirates of the Caribbean: At World's End
# 2  206647                en                                   Spectre
# 3   49026                en                     The Dark Knight Rises
# 4   49529                en                               John Carter
#
#                                             overview  popularity release_date  \
# ...

# %% [markdown]
# 1. Zwróć listę 10 najwyżej ocenianych filmów (vote_average), których liczba głosów (vote_count) jest większa od 3. kwartyla rozkładu liczby głosów.

# %%
Q75=movies['vote_count'].quantile(0.75)
movies[movies['vote_count']>Q75].sort_values(by='vote_average',ascending=False).head(10)
# Out:
#       Unnamed: 0    budget                                    homepage  \
# 1881        1881  25000000                                         NaN
# 3337        3337   6000000                http://www.thegodfather.com/
# 2294        2294  15000000      http://movies.disney.com/spirited-away
# 3865        3865   3300000           http://sonyclassics.com/whiplash/
# 2731        2731  13000000                                         NaN
# 3232        3232   8000000                                         NaN
# 1818        1818  22000000              http://www.schindlerslist.com/
# 662          662  63000000  http://www.foxmovies.com/movies/fight-club
# 2170        2170    806948                                         NaN
# 1847        1847  25000000        http://www.warnerbros.com/goodfellas
#
#           id original_language            original_title  \
# 1881     278                en  The Shawshank Redemption
# 3337     238                en             The Godfather
# ...

# %% [markdown]
# 2. Pogrupuj tabelę w taki sposób, aby otrzymać średni przychód (revenue) oraz średni budżet (budget) w danym roku dla filmów opublikowanych od 2010 (włącznie) do 2016 roku (włącznie). Następnie na tej podstawie stwórz wykres, w którym średnie przychody są wykresem kolumnowym, a średni budżet wykresem liniowym na tych samych osiach. Sformatuj odpowiednio oś X oraz oś Y. Dodaj tytuł wykresu, oraz legendę, która znajduje się w prawym górnym rogu płótna, lecz poza obszarem osi. Przykład wykresu widoczny poniżej:

# %%
movies['release_date'] = pd.to_datetime(movies['release_date'])
movies['release_date']=movies['release_date'].dt.year
mask = (movies['release_date'] > 2010) & (movies['release_date'] <= 2016)
movies_by_date=movies.loc[mask].groupby('release_date')[['budget', 'revenue']].mean()

# %%
movies_by_date=movies_by_date.reset_index()
def million(x, pos):
        return '{:2.1f}M'.format(x*1e-6)

fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
formatter = plt.FuncFormatter(million)
axes.yaxis.set_major_formatter(formatter)

axes.plot(movies_by_date['release_date'],movies_by_date['budget'],label='budget',color = 'red')
axes.bar (movies_by_date['release_date'],movies_by_date['revenue'],label='revenue')
axes.legend(loc=(1.05,0.85))
axes.set_title('Średni przychód i budżet filmu w latach 2010-2016')
# Out:
# Text(0.5, 1.0, 'Średni przychód i budżet filmu w latach 2010-2016')

# %% [markdown]
# 3. Baza filmów zawiera kolumnę z id gatunku (genre_id). Na tej podstawie połącz ze sobą bazę filmów z bazą gatunków, tak aby w bazie filmów można było odczytać nazwę gatunku filmu.

# %%
count_genres=movies.pivot_table(values='id',index='genre_id',aggfunc='count').sort_values(by='genre_id',ascending=False)
genres_dict = dict(zip(genres['genre_id'].unique(),genres['genres']))
movies['genre'] = movies['genre_id'].map(genres_dict)
movies.head()
# Out:
#    Unnamed: 0     budget                                      homepage  \
# 0           0  237000000                   http://www.avatarmovie.com/
# 1           1  300000000  http://disney.go.com/disneypictures/pirates/
# 2           2  245000000   http://www.sonypictures.com/movies/spectre/
# 3           3  250000000            http://www.thedarkknightrises.com/
# 4           4  260000000          http://movies.disney.com/john-carter
#
#        id original_language                            original_title  \
# 0   19995                en                                    Avatar
# 1     285                en  Pirates of the Caribbean: At World's End
# 2  206647                en                                   Spectre
# 3   49026                en                     The Dark Knight Rises
# 4   49529                en                               John Carter
#
#                                             overview  popularity  \
# ...

# %% [markdown]
# 4.Jaki gatunek filmu z bazy pojawia się w niej najczęściej? Ile filmów tego gatunku znajduje się w bazie?

# %%
count_genres=movies.pivot_table(values='id',index='genre',aggfunc='count').sort_values(by='id',ascending=False)
count_genres.head()
# Out:
#              id
# genre
# Drama      1207
# Comedy     1042
# Action      754
# Adventure   339
# Horror      300

# %% [markdown]
# odp. Najczęściej pojawiającym się gatunkiem jest: Drama - 1207 wystąpień

# %% [markdown]
# 5. Filmy, którego gatunku trwają średnio najdłużej (runtime)?

# %%
mean_runtime=movies.pivot_table(values='runtime',index='genre',aggfunc='mean').sort_values(by='runtime',ascending=False).round()
mean_runtime.head(5)
# Out:
#            runtime
# genre
# History      134.0
# War          126.0
# Western      118.0
# Drama        116.0
# Adventure    113.0

# %% [markdown]
# odp. Średnio najdłużej twają filmy gatunku: History.

# %% [markdown]
# 6. Stwórz histogram czasu trwania filmów z gatunku, który cechuje się największym średnim czasem trwania.

# %%
history_movies=movies[movies['genre']=='History']
history_movies['runtime'].hist(bins=15)
# Out:
# <AxesSubplot: >
